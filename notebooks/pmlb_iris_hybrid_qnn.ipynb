# %% [markdown]
# # Iris — Hybrid QNN vs Classical Baseline
#
# Notebook wrapper: runs the smoke training script `run_iris_smoke.py` which trains three models (Baseline MLP, QNN linear concat, MyMethod FiLM+gate) on the PMLB `iris` dataset.

# %%
# %run ../run_iris_smoke.py
